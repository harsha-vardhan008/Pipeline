# %% [markdown]
# 1. Processing customer data from a CSV file for a retail company to ensure clean, unique records.
# Tasks involved: Deduplication, Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Harshavardhan\Downloads\us_customer_data 1.csv")

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.head()
# Out:
#    customer_id              name                        email         phone  \
# 0            1     Michelle Kidd           vayala@example.net  619-723-4258
# 1            2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2            3      Larry Torres         dsanchez@example.net  810-256-4505
# 3            4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4            5  Matthew Phillips        qwilliams@example.com  220-763-3522
#
#                                              address registration_date  \
# 0                        USNS Santiago, FPO AE 80872        25-01-2025
# 1  38783 Oliver Street, West Kristenborough, MT 9...        13-07-2023
# 2     6845 Steele Turnpike, West Erikabury, UT 37487        18-08-2023
# 3         1631 Alexis Meadows, Lake Amanda, CA 75179        08-12-2024
# 4  2274 Williams Heights Suite 895, Andersonhaven...        03-02-2024
#
#   loyalty_status
# 0           Gold
# 1         Silver
# 2         Bronze
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                50
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df['email']=df['email'].fillna(df['name'].str.replace(' ','').str.lower()+'@example.com')

# %%
df
# Out:
#      customer_id              name                        email         phone  \
# 0              1     Michelle Kidd           vayala@example.net  619-723-4258
# 1              2       Brad Newton  taylorcatherine@example.net  537-674-1158
# 2              3      Larry Torres         dsanchez@example.net  810-256-4505
# 3              4    Kimberly Price    jessicaknight@example.com  423-222-9779
# 4              5  Matthew Phillips        qwilliams@example.com  220-763-3522
# ..           ...               ...                          ...           ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  638-989-9441
# 996          997      Jodi Simpson           eric24@example.org  483-625-2940
# 997          998     Crystal Brown         pshaffer@example.net  390-747-3088
# 998          999    Gregory Duarte    caitlindunlap@example.org  257-409-8196
# 999         1000       Jason Walls        michael42@example.com  692-333-6880
#
# ...

# %%
df.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df.loc[4]
# Out:
# customer_id                                                          5
# name                                                  Matthew Phillips
# email                                            qwilliams@example.com
# phone                                                     220-763-3522
# address              2274 Williams Heights Suite 895, Andersonhaven...
# registration_date                                           03-02-2024
# loyalty_status                                                    Gold
# Name: 4, dtype: object

# %%
df.loc[296]
df.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df.loc[296]
# Out:
# customer_id                                                        297
# name                                                    Bryan Marshall
# email                                             daniel62@example.net
# phone                                                                e
# address              86370 Charles Loop Apt. 517, Madelineborough, ...
# registration_date                                           30-06-2024
# loyalty_status                                                  Silver
# Name: 296, dtype: object

# %%
df.loc[296]
# Out:
# customer_id                                                        297
# name                                                    Bryan Marshall
# email                                             daniel62@example.net
# phone                                                                e
# address              86370 Charles Loop Apt. 517, Madelineborough, ...
# registration_date                                           30-06-2024
# loyalty_status                                                  Silver
# Name: 296, dtype: object

# %%
df.isna().sum()
df.loc[444]
# Out:
# customer_id                                                        445
# name                                                      Mallory Mann
# email                                            charles11@example.net
# phone                                                   899-580-4(497)
# address              14758 Bautista Fords Apt. 251, Sandrachester, ...
# registration_date                                           23-10-2024
# loyalty_status                                                    Gold
# Name: 444, dtype: object

# %%
df['phone'] =df['phone'].str.replace(r'[^0-9]','',regex=True)
df.loc[444]
# Out:
# customer_id                                                        445
# name                                                      Mallory Mann
# email                                            charles11@example.net
# phone                                                       8995804497
# address              14758 Bautista Fords Apt. 251, Sandrachester, ...
# registration_date                                           23-10-2024
# loyalty_status                                                    Gold
# Name: 444, dtype: object

# %%
df['phone']=df['phone'].str.slice(0,10)
df.loc[444]
# Out:
# customer_id                                                        445
# name                                                      Mallory Mann
# email                                            charles11@example.net
# phone                                                       8995804497
# address              14758 Bautista Fords Apt. 251, Sandrachester, ...
# registration_date                                           23-10-2024
# loyalty_status                                                    Gold
# Name: 444, dtype: object

# %%
#df['phone'] =df['phone'].str.replace(r'[a-zA-Z]','xxx-xxx-xxxx',regex=True)

# %%
df.loc[306]
# Out:
# customer_id                                                       307
# name                                                    Courtney Reed
# email                                            xhopkins@example.net
# phone                                                             NaN
# address              8858 Joshua Square Suite 148, Johnbury, OH 85434
# registration_date                                          04-09-2024
# loyalty_status                                                   Gold
# Name: 306, dtype: object

# %%
df.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df.loc[290]
# Out:
# customer_id                                            291
# name                                             Adam Cook
# email                           jacksonsuzanne@example.net
# phone                                           2836907680
# address              334 Cheryl Manor, New Allen, MI 73722
# registration_date                               01-03-2025
# loyalty_status                                      Bronze
# Name: 290, dtype: object

# %%
df.loc[296]
df.isna().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                16
# address               0
# registration_date     0
# loyalty_status        0
# dtype: int64

# %%
df['phone']=df['phone'].fillna('xxx-xxx-xxxx')

# %%
df.isna().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# dtype: int64

# %%
df.loc[df['phone'].str.len()<10,'phone']='xxx-xxx-xxxx'

# %%
df.to_csv('test18.csv',index=False)

# %% [markdown]
# #   2. Standardizing contact details in an Excel file for a marketing campaign using  customer data  Tasks involved: Cleaning, Mapping

# %%
df1=pd.read_csv(r'test18.csv')

# %%
df1['country_code']=df1['address'].str.slice(-8,-6)

# %%
df1['country_code']
# Out:
# 0      AE
# 1      MT
# 2      UT
# 3      CA
# 4      OR
#        ..
# 995    AS
# 996    AL
# 997    DE
# 998    AP
# 999    MH
# Name: country_code, Length: 1000, dtype: object

# %%
df2=pd.read_csv(r"C:\Users\Harshavardhan\Downloads\countrycodes.csv")

# %%
df2.describe()
# Out:
#             Country ISO2 CallingCode
# count           187  186         187
# unique          187  186         185
# top     Afghanistan   AF           1
# freq              1    1           2

# %%
df2['Country']
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3          Andorra
# 4           Angola
#           ...
# 182      Venezuela
# 183        Vietnam
# 184          Yemen
# 185         Zambia
# 186       Zimbabwe
# Name: Country, Length: 187, dtype: object

# %%
df2=df2.drop(columns= 'Country')

# %%
df2.describe()
# Out:
#        ISO2 CallingCode
# count   186         187
# unique  186         185
# top      AF           1
# freq      1           2

# %%
df2=df2.rename(columns={'ISO2':'country_code'})

# %%
df2.describe()
# Out:
#        country_code CallingCode
# count           186         187
# unique          186         185
# top              AF           1
# freq              1           2

# %%
dff=pd.merge(df1,df2,on='country_code',how='left')

# %%
dff
# Out:
#      customer_id              name                        email       phone  \
# 0              1     Michelle Kidd           vayala@example.net  6197234258
# 1              2       Brad Newton  taylorcatherine@example.net  5376741158
# 2              3      Larry Torres         dsanchez@example.net  8102564505
# 3              4    Kimberly Price    jessicaknight@example.com  4232229779
# 4              5  Matthew Phillips        qwilliams@example.com  2207633522
# ..           ...               ...                          ...         ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net  6389899441
# 996          997      Jodi Simpson           eric24@example.org  4836252940
# 997          998     Crystal Brown         pshaffer@example.net  3907473088
# 998          999    Gregory Duarte    caitlindunlap@example.org  2574098196
# 999         1000       Jason Walls        michael42@example.com  6923336880
#
# ...

# %%
dff['CallingCode']=dff['CallingCode'].fillna(1)

# %%
dff['phone']='+'+dff['CallingCode'].astype(str)+'-'+dff['phone']

# %%
dff['phone']
# Out:
# 0      +971-6197234258
# 1      +356-5376741158
# 2        +1-8102564505
# 3        +1-4232229779
# 4        +1-2207633522
#             ...
# 995      +1-6389899441
# 996    +355-4836252940
# 997     +49-3907473088
# 998      +1-2574098196
# 999    +692-6923336880
# Name: phone, Length: 1000, dtype: object

# %%
dff.isna().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# country_code         0
# CallingCode          0
# dtype: int64

# %%
dff.head()
# Out:
#    customer_id              name                        email  \
# 0            1     Michelle Kidd           vayala@example.net
# 1            2       Brad Newton  taylorcatherine@example.net
# 2            3      Larry Torres         dsanchez@example.net
# 3            4    Kimberly Price    jessicaknight@example.com
# 4            5  Matthew Phillips        qwilliams@example.com
#
#              phone                                            address  \
# 0  +971-6197234258                        USNS Santiago, FPO AE 80872
# 1  +356-5376741158  38783 Oliver Street, West Kristenborough, MT 9...
# 2    +1-8102564505     6845 Steele Turnpike, West Erikabury, UT 37487
# 3    +1-4232229779         1631 Alexis Meadows, Lake Amanda, CA 75179
# 4    +1-2207633522  2274 Williams Heights Suite 895, Andersonhaven...
#
#   registration_date loyalty_status country_code CallingCode
# 0        25-01-2025           Gold           AE         971
# ...

# %%
dff.to_csv('Test3.csv',index=False)

# %%
dff
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              2       Brad Newton  taylorcatherine@example.net
# 2              3      Larry Torres         dsanchez@example.net
# 3              4    Kimberly Price    jessicaknight@example.com
# 4              5  Matthew Phillips        qwilliams@example.com
# ..           ...               ...                          ...
# 995          996    Jerry Mcdaniel       walkerlisa@example.net
# 996          997      Jodi Simpson           eric24@example.org
# 997          998     Crystal Brown         pshaffer@example.net
# 998          999    Gregory Duarte    caitlindunlap@example.org
# 999         1000       Jason Walls        michael42@example.com
#
#                phone                                            address  \
# 0    +971-6197234258                        USNS Santiago, FPO AE 80872
# ...

# %% [markdown]
# # 3. Filtering high-value transactions from a CSV file for targeted promotions.                      Tasks involved: Filtering, Cleaning

# %%
dff1=pd.read_csv(r'c:\Users\Harshavardhan\Downloads\transaction_data.csv')

# %%
dff.loc[444]
# Out:
# customer_id                                                        445
# name                                                      Mallory Mann
# email                                            charles11@example.net
# phone                                                    +1-8995804497
# address              14758 Bautista Fords Apt. 251, Sandrachester, ...
# registration_date                                           23-10-2024
# loyalty_status                                                    Gold
# country_code                                                        NJ
# CallingCode                                                          1
# Name: 444, dtype: object

# %%
merge=pd.merge(dff,dff1,on='customer_id',how='inner')

# %%
mvp=merge[merge['amount']>1000]
mvp
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 990          991     Erica Fleming          erica85@example.net
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
#
#                phone                                            address  \
# 0    +971-6197234258                        USNS Santiago, FPO AE 80872
# ...

# %%
merge['amount']=merge['amount'].fillna(merge['amount'].mean())
merge.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# country_code         0
# CallingCode          0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
mvp=merge[merge['amount']>1000]
mvp
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 6             10      Rachel White     whitemichael@example.org
# ..           ...               ...                          ...
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org
# 993          995    Deanna Johnson            ycook@example.org
# 994          995    Deanna Johnson            ycook@example.org
# 999          998     Crystal Brown         pshaffer@example.net
#
#                phone                                            address  \
# 0    +971-6197234258                        USNS Santiago, FPO AE 80872
# ...
